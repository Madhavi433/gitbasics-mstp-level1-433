# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_orig_rc_params',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'external',
#  'factorplot',
#  'get_dataset_names',
#  'heatmap',
#  'hls_palette',
#  'husl_palette',
#  'jointplot',
#  'kdeplot',
#  'light_palette',
#  'lineplot',
#  'lmplot',
#  'load_dataset',
#  'lvplot',
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
x=np.random.rand(20)
y=np.random.rand(20)
plt.plot(x,y,"ko",alpha=0.1,linewidth=2,markersize=12)

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
help(sns.set)
# Out:
# Help on function set in module seaborn.rcmod:
#
# set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
#     Set aesthetic parameters in one step.
#
#     Each set of parameters can be set directly or temporarily, see the
#     referenced functions below for more information.
#
#     Parameters
#     ----------
#     context : string or dict
#         Plotting context parameters, see :func:`plotting_context`
#     style : string or dict
#         Axes style parameters, see :func:`axes_style`
#     palette : string or sequence
#         Color palette, see :func:`color_palette`
#     font : string
#         Font family, see matplotlib font manager.
#     font_scale : float, optional
#         Separate scaling factor to independently scale the size of the
#         font elements.
#     color_codes : bool
#         If ``True`` and ``palette`` is a seaborn palette, remap the shorthand
# ...

# %%
sns.set(color_codes=True)
plt.plot(x,y)

# %%
sns.set(palette="muted")
plt.plot(x,y)

# %%
import pandas as pd
data=pd.DataFrame({'x':[2,3,4,5],'y':[7,9,6,5]})
data
# Out:
#    x  y
# 0  2  7
# 1  3  9
# 2  4  6
# 3  5  5

# %%
data['x']
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# Name: x, dtype: int64

# %%
data['y']
# Out:
# 0    7
# 1    9
# 2    6
# 3    5
# Name: y, dtype: int64

# %%
plt.plot(data['x'],data['y'],'gs')

# %% [markdown]
# ### Relation plot(high level functioning plot)
# # Scatter
# # line

# %%
data
# Out:
#    x  y
# 0  2  7
# 1  3  9
# 2  4  6
# 3  5  5

# %%
help(sns.relplot)
# Out:
# Help on function relplot in module seaborn.relational:
#
# relplot(x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='brief', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)
#     Figure-level interface for drawing relational plots onto a FacetGrid.
#
#     This function provides access to several different axes-level functions
#     that show the relationship between two variables with semantic mappings
#     of subsets. The ``kind`` parameter selects the underlying axes-level
#     function to use:
#
#     - :func:`scatterplot` (with ``kind="scatter"``; the default)
#     - :func:`lineplot` (with ``kind="line"``)
#
#     Extra keyword arguments are passed to the underlying function, so you
# ...

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,kind="line")

# %%
sns.set()
sns.relplot(x='x',y='y',data=data)

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,kind="line",size=5,markers=5)

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,kind="line",size=0.6,markers=['x','m'])

# %%
sns.set()
sns.relplot(x='x',y='y',hue="y",data=data,kind="line",size=0.6)

# %% [markdown]
# ## Loading a datasets

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set(style="darkgrid")
k=sns.load_dataset("tips")
k.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill",y="day",data=k)

# %%
sns.relplot(x="total_bill",y="day",data=k,hue="tip")

# %%
sns.relplot(x="total_bill",y="size",data=k,hue="tip",kind="line")

# %%
sns.set(style="darkgrid")
d=sns.load_dataset("iris")
d.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x="species",y="petal_length",data=d)

# %%
sns.relplot(x="species",y="petal_length",col="species",data=d)

# %%
d['species'].value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
sns.relplot(x="species",y="petal_length",col="species",data=d,hue="species")

# %%
sns.relplot("total_bill","tip",data=k,style="smoker",size="size")

# %%
sns.relplot("total_bill","tip",data=k,style="smoker",size="size",col="time",legend="full")

# %% [markdown]
# ## linear regression model plot

# %%
sns.lmplot("total_bill","tip",data=k)

# %%
sns.relplot("total_bill","tip",data=k,hue="smoker")

# %%
sns.relplot("total_bill","tip",data=k,hue="smoker",col="time")

# %% [markdown]
# ### categorical data plot
# # cat plot
#    #Swarm plot
#    #scatter plot
#    #Bar plot
#    #violin plot

# %%
sns.catplot(x="species",y="sepal_length",data=d)

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=d)

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=d,kind="swarm")

# %%
sns.catplot(x="species",y="petal_length",data=d,kind="violin")

# %%
sns.catplot(x="species",y="petal_length",data=d,kind="bar")

# %%
## Box plot
d,axs=plt.subplots(1,2)

# %%
d,axs=plt.subplots(1,2)
sns.boxplot(x="species",y="sepal_length",data=k,ax=axs[0])
sns.scatterplot(x="species",y="sepal_length",data=k,ax=axs[1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-1ce29b1f73d5> in <module>
#       1 d,axs=plt.subplots(1,2)
# ----> 2 sns.boxplot(x="species",y="sepal_length",data=k,ax=axs[0])
#       3 sns.scatterplot(x="species",y="sepal_length",data=k,ax=axs[1])
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ...

# %%
sns.boxplot(x="total_bill",y="day",data=k)

# %%
sns.swarmplot(x="total_bill",y="day",data=k)

# %% [markdown]
# ## Visualisation of data set
#   #jointplot
#   #kde-kernal density
#   #hex
#   #scatter
#   #reg
#   #resig

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sns.jointplot(x="total_bill",y="tip",data=k)

# %%
sns.jointplot(x="total_bill",y="tip",data=k,kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",hue="smoker",data=k,kind="kde")
# Out:
# C:\Users\kvsw5\Anaconda3\lib\site-packages\seaborn\distributions.py:423: UserWarning: The following kwargs were not used by contour: 'hue'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)

# %%
sns.jointplot(x="total_bill",y="tip",data=k,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=k,kind="reg",color='g')

# %%
sns.jointplot(x="total_bill",y="tip",data=k,kind="reg",color='g',height=3.5,ratio=9)

# %% [markdown]
# ### Pair plot

# %%
sns.pairplot(data=k)

# %%
sns.pairplot(data=k,hue="day")

# %%
sns.pairplot(k,vars=["total_bill","tip"])

# %%
sns.pairplot(k,diag_kind="kde")

# %%
sns.pairplot(k,diag_kind="kde",markers="+")

# %% [markdown]
# ### Distributed plot

# %%
x=np.random.rand(55)
sns.distplot(x)

# %% [markdown]
# ## facetgrid plot

# %%
ff=sns.FacetGrid(k,col="day")
ff.map(plt.hist,"total_bill")

# %% [markdown]
# # pairgrid

# %%
sns.PairGrid(k)

# %%
sns.set(style="ticks")
pp=sns.PairGrid(k)
pp.map(plt.scatter)
